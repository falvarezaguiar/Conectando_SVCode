# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# 2-title.png

# %% [markdown]
# ![imagen.png](attachment:5892db26-3cab-48fb-82c1-6711efad429d.png)

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# Some of the popular languages that Data Scientist use are:
# 1. R
# 2. Python
# 3. C++

# %% [markdown]
# ![imagen.png](attachment:4a28fa6c-ffe6-4aea-ae87-c8413553fa93.png)

# %% [markdown]
# Somo of the commonluy used libraries used by Data Scientist include:
# 1. skickt-lear
# 2. tensor flow
# 3. matplot
# 4. pandas
# 5. numpy

# %% [markdown]
# Example of table

# %% [markdown]
# | Columna A | Columna B |
# | :--- | :--- |
# | Celda 1 | Celda 2 |
# | Celda 3 | Celda 4 |

# %% [markdown]
# Exercise 8 a code cell to multiply and add numbers

# %% [raw]
# (3*4)+5

# %% [markdown]
# Exercise 9 - Create a code cell to convert minutes to hours

# %%
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# Exercise 10 - Create a markdown cell to list Objetives

# %% [markdown]
# **Objectives:**
#
# * List popular languages for Data Science.
# * Describe the purpose of Jupiter Notebooks.
# * Identify the main components of Jupyter's architecture (Client, Server, Kernel).
# * Explain the difference between Continuous Integration (CI) and Continuous Delivery (CD).
# * Demonstrate how to create a local clone of a Git repository.

# %% [markdown]
# Exercise 11 - Create a markdown cell to indicate the Autor´s name

# %% [markdown]
# ## Author
# Pakito de Xochi
